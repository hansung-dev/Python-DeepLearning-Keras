# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 4.4 네이버 주식 데이터로 종가 예측
#
# ## 4.2.2 데이터 구성 및 준비 (pandas-datareader)

# %%
import pandas_datareader.data as web

data = web.DataReader('035420', 'naver', start='2011-01-01', end='2022-06-30')

print(data.shape)
data.tail()
# Out:
# (2832, 5)
#               Open    High     Low   Close  Volume
# Date
# 2022-06-24  238500  250000  236000  247500  990710
# 2022-06-27  247500  253500  244500  249000  634239
# 2022-06-28  248500  253000  246000  252500  460119
# 2022-06-29  246500  249000  244500  246500  464699
# 2022-06-30  241500  245000  236500  240000  764891

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2832 entries, 2011-01-03 to 2022-06-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    2832 non-null   object
#  1   High    2832 non-null   object
#  2   Low     2832 non-null   object
#  3   Close   2832 non-null   object
#  4   Volume  2832 non-null   object
# dtypes: object(5)
# memory usage: 132.8+ KB

# %% [markdown]
# ## 4.4.3 데이터 전처리

# %%
data = data.astype('int')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2832 entries, 2011-01-03 to 2022-06-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    2832 non-null   int64
#  1   High    2832 non-null   int64
#  2   Low     2832 non-null   int64
#  3   Close   2832 non-null   int64
#  4   Volume  2832 non-null   int64
# dtypes: int64(5)
# memory usage: 132.8 KB

# %%
# 데이터 분할
train_df = data['2011-1':'2020-12'].copy()
val_df = data['2021-1':'2021-12'].copy()
test_df = data['2022-1':].copy()

print('train_df.shape'  , train_df.shape)
print('val_df.shape'    , val_df.shape)
print('test_df.shape'   , test_df.shape)
# Out:
# train_df.shape (2463, 5)
# val_df.shape (248, 5)
# test_df.shape (121, 5)

# %%
# 데이터 정규화(Normalization)
train_max = train_df.max()
train_min = train_df.min()

train_df = (train_df - train_min) / (train_max - train_min)
val_df = (val_df - train_min) / (train_max - train_min)
test_df = (test_df - train_min) / (train_max - train_min)

train_df.head()
# Out:
#                 Open      High       Low     Close    Volume
# Date
# 2011-01-03  0.213297  0.207602  0.205221  0.051382  0.028787
# 2011-01-04  0.208175  0.203986  0.202425  0.051382  0.028788
# 2011-01-05  0.203988  0.205798  0.204291  0.052488  0.035352
# 2011-01-06  0.209107  0.203986  0.204755  0.051382  0.036038
# 2011-01-07  0.206318  0.205798  0.206624  0.055251  0.038215

# %%
from tensorflow.keras.preprocessing import timeseries_dataset_from_array

window_length = 7

x_train = train_df.values
y_train = train_df['Close'].iloc[window_length:]

train_ds = timeseries_dataset_from_array(
            x_train, y_train,
            sequence_length=window_length,
            batch_size=32
)

for batch in train_ds.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# Input shape: (32, 7, 5)
# Target shape: (32,)

# %%
from tensorflow.keras.preprocessing import timeseries_dataset_from_array

window_length = 7

x_val = val_df.values
y_val = val_df['Close'].iloc[window_length:]

val_ds = timeseries_dataset_from_array(
    x_val, y_val,
    sequence_length=window_length,
    batch_size=32
)

for batch in val_ds.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# Input shape: (32, 7, 5)
# Target shape: (32,)

# %% [markdown]
# ## 4.4.4 모델 생성

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, LSTM, Dense

inputs = Input(shape=(7, 5))
x = LSTM(32)(inputs)
outputs = Dense(1)(x)

model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 7, 5)]            0
#
#  lstm (LSTM)                 (None, 32)                4864
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 4,897
# Trainable params: 4,897
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 4.4.5 모델 학습

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

earlyetopping_callback = EarlyStopping(monitor="val_loss", 
                                       patience=10)

modelcheckpoint_callback = ModelCheckpoint(filepath="best_checkpoint_model.h5", 
                                           monitor="val_loss", 
                                           save_weights_only=True, 
                                           save_best_only=True, 
                                           verbose=1)

# %%
# %%time

history = model.fit(train_ds,
    epochs=100,
    validation_data=val_ds,
    batch_size = 32,
    callbacks=[earlyetopping_callback, modelcheckpoint_callback]
)
# Out:
# Epoch 1/100
# 76/77 [============================>.] - ETA: 0s - loss: 0.0068 - mae: 0.0623
# Epoch 1: val_loss improved from inf to 0.06743, saving model to best_checkpoint_model.h5
# 77/77 [==============================] - 7s 33ms/step - loss: 0.0068 - mae: 0.0626 - val_loss: 0.0674 - val_mae: 0.2494
# Epoch 2/100
# 73/77 [===========================>..] - ETA: 0s - loss: 0.0066 - mae: 0.0538
# Epoch 2: val_loss improved from 0.06743 to 0.01217, saving model to best_checkpoint_model.h5
# 77/77 [==============================] - 1s 17ms/step - loss: 0.0064 - mae: 0.0527 - val_loss: 0.0122 - val_mae: 0.0981
# Epoch 3/100
# 75/77 [============================>.] - ETA: 0s - loss: 5.2926e-04 - mae: 0.0173
# Epoch 3: val_loss improved from 0.01217 to 0.01160, saving model to best_checkpoint_model.h5
# 77/77 [==============================] - 1s 17ms/step - loss: 5.2894e-04 - mae: 0.0174 - val_loss: 0.0116 - val_mae: 0.0958
# Epoch 4/100
# 75/77 [============================>.] - ETA: 0s - loss: 4.2697e-04 - mae: 0.0144
# Epoch 4: val_loss improved from 0.01160 to 0.01073, saving model to best_checkpoint_model.h5
# 77/77 [==============================] - 1s 17ms/step - loss: 4.2872e-04 - mae: 0.0145 - val_loss: 0.0107 - val_mae: 0.0914
# Epoch 5/100
# 74/77 [===========================>..] - ETA: 0s - loss: 4.0781e-04 - mae: 0.0145
# Epoch 5: val_loss did not improve from 0.01073
# 77/77 [==============================] - 1s 15ms/step - loss: 4.2340e-04 - mae: 0.0148 - val_loss: 0.0111 - val_mae: 0.0936
# Epoch 6/100
# 76/77 [============================>.] - ETA: 0s - loss: 3.8015e-04 - mae: 0.0136
# Epoch 6: val_loss improved from 0.01073 to 0.00988, saving model to best_checkpoint_model.h5
# 77/77 [==============================] - 2s 19ms/step - loss: 3.7934e-04 - mae: 0.0136 - val_loss: 0.0099 - val_mae: 0.0874
# Epoch 7/100
# 75/77 [============================>.] - ETA: 0s - loss: 3.6984e-04 - mae: 0.0136
# Epoch 7: val_loss improved from 0.00988 to 0.00958, saving model to best_checkpoint_model.h5
# 77/77 [==============================] - 1s 17ms/step - loss: 3.7283e-04 - mae: 0.0137 - val_loss: 0.0096 - val_mae: 0.0861
# Epoch 8/100
# 72/77 [===========================>..] - ETA: 0s - loss: 2.9952e-04 - mae: 0.0124
# Epoch 8: val_loss improved from 0.00958 to 0.00875, saving model to best_checkpoint_model.h5
# 77/77 [==============================] - 1s 10ms/step - loss: 3.5202e-04 - mae: 0.0133 - val_loss: 0.0088 - val_mae: 0.0817
# Epoch 9/100
# 72/77 [===========================>..] - ETA: 0s - loss: 2.8713e-04 - mae: 0.0122
# Epoch 9: val_loss improved from 0.00875 to 0.00813, saving model to best_checkpoint_model.h5
# 77/77 [==============================] - 1s 11ms/step - loss: 3.4020e-04 - mae: 0.0132 - val_loss: 0.0081 - val_mae: 0.0784
# Epoch 10/100
# 71/77 [==========================>...] - ETA: 0s - loss: 2.7020e-04 - mae: 0.0120
# Epoch 10: val_loss improved from 0.00813 to 0.00770, saving model to best_checkpoint_model.h5
# 77/77 [==============================] - 1s
# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scattergl(y=history.history['loss'],name='loss'))
fig.add_trace(go.Scattergl(y=history.history['val_loss'],name='val_loss'))
fig.update_layout(title="<b>Loss of Model</b>", xaxis_title='Epoch',yaxis_title='Loss', template='seaborn')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="10cdd9c9-bcbf-40d9-be06-9b06ad5f0e34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10cdd9c9-bcbf-40d9-be06-9b06ad5f0e34")) {                    Plotly.newPlot(                        "10cdd9c9-bcbf-40d9-be06-9b06ad5f0e34",                        [{"name":"loss","y":[0.006764520425349474,0.006403026636689901,0.0005289373802952468,0.00042872270569205284,0.0004234031948726624,0.00037933597923256457,0.00037282975972630084,0.00035202098661102355,0.0003401964495424181,0.0003295968344900757,0.0003270019660703838,0.00033965668990276754,0.0003724121779669076,0.00041819532634690404,0.00045193464029580355,0.00044667060137726367,0.00040641770465299487,0.00035927467979490757,0.00032387510873377323,0.00030423025600612164,0.0002982780570164323,0.00030326470732688904],"type":"scattergl"},{"name":"val_loss","y":[0.0674283504486084,0.012170271947979927,0.011603819206357002,0.010725202970206738,0.011091453954577446,0.009875058196485043,0.009576196782290936,0.008753277361392975,0.008131513372063637,0.0076980735175311565,0.007501177489757538,0.007461723405867815,0.007466507609933615,0.00748103903606534,0.00755680538713932,0.007696883752942085,0.007821457460522652,0.0079184640198946,0.008020796813070774,0.008105168119072914,0.008154562674462795,0.008168293163180351],"type":"scattergl"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122) ...

# %% [markdown]
# ## 4.4.7 모델 예측

# %%
model.load_weights('best_checkpoint_model.h5')

# %%
from tensorflow.keras.preprocessing import timeseries_dataset_from_array

window_length = 7

x_test = test_df.values
y_test = test_df['Close'].iloc[window_length:]

test_ds = timeseries_dataset_from_array(
    x_test, y_test,
    sequence_length=window_length,
    batch_size=32
)

for batch in test_ds.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# Input shape: (32, 7, 5)
# Target shape: (32,)

# %%
test_numpy = test_df['Close'][7:].to_numpy()
pred = model.predict(test_ds)

print(test_numpy.shape)
print(pred.shape)
# Out:
# 4/4 [==============================] - 1s 7ms/step
# (114,)
# (114, 1)

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scattergl(y=test_numpy, name='actual'))
fig.add_trace(go.Scattergl(y=pred.reshape(114,), name='prediction'))
fig.update_layout(title="<b>네이버 주식 종가 예측</b>", xaxis_title='Date',yaxis_title='Close', template='seaborn')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f8f5eaec-8074-4a58-9a90-e8da492aeb2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8f5eaec-8074-4a58-9a90-e8da492aeb2b")) {                    Plotly.newPlot(                        "f8f5eaec-8074-4a58-9a90-e8da492aeb2b",                        [{"name":"actual","y":[1.0228819257428705,1.0316826664132053,1.0105608888044018,1.0158413332066027,0.9964797037318661,0.9771180742571295,0.9859188149274642,0.9788782223911965,0.9630368891845937,0.9401549634417232,0.908472297028518,0.8732693343471787,0.8979114082241162,0.9348745190395223,0.9595165929