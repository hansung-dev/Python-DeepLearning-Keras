# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1.4 보스턴 주택 가격 예측 (회귀)

# %% [markdown]
# ## 1.4.2 데이터 구성 및 준비

# %%
import tensorflow as tf
from tensorflow import keras

print('tensorflow version:', tf.__version__)
print('keras version:', keras.__version__)
# Out:
# tensorflow version: 2.10.0
# keras version: 2.10.0

# %%
from tensorflow.keras import datasets

boston_housing = datasets.boston_housing
(x_train, y_train),(x_test, y_test) = boston_housing.load_data()

print('\ntrain data:', x_train.shape, y_train.shape)
print('test data:',x_test.shape, y_test.shape)
# Out:
# train data: (404, 13) (404,)
# test data: (102, 13) (102,)

# %% [markdown]
# ## 1.4.3 모델 생성 및 학습

# %%
tf.random.set_seed(0)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import Input
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Input(shape=(13,)))
model.add(Dense(units=64, activation="relu"))
model.add(Dense(units=64, activation="relu"))
model.add(Dense(units=1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                896
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='RMSprop',
              loss='mse',
              metrics=['mae', 'mse'])

# %%
model.fit(x_train, y_train, 
          validation_split = 0.2,
          epochs=5)
# Out:
# Epoch 1/5
# 11/11 [==============================] - 1s 48ms/step - loss: 778.9368 - mae: 17.3649 - mse: 778.9368 - val_loss: 102.4213 - val_mae: 6.6713 - val_mse: 102.4213
# Epoch 2/5
# 11/11 [==============================] - 0s 8ms/step - loss: 73.5311 - mae: 6.2310 - mse: 73.5311 - val_loss: 185.2809 - val_mae: 10.4324 - val_mse: 185.2809
# Epoch 3/5
# 11/11 [==============================] - 0s 11ms/step - loss: 113.2928 - mae: 8.3161 - mse: 113.2928 - val_loss: 132.2689 - val_mae: 10.3259 - val_mse: 132.2689
# Epoch 4/5
# 11/11 [==============================] - 0s 12ms/step - loss: 90.5908 - mae: 7.3359 - mse: 90.5908 - val_loss: 157.1337 - val_mae: 9.2553 - val_mse: 157.1337
# Epoch 5/5
# 11/11 [==============================] - 0s 9ms/step - loss: 100.9222 - mae: 7.9271 - mse: 100.9222 - val_loss: 88.0356 - val_mae: 7.5803 - val_mse: 88.0356

# %% [markdown]
# ## 1.4.4 모델 평가 및 예측

# %%
loss, mae, mse = model.evaluate(x_test, y_test, verbose=2)

print('\nloss :', loss)
print('mae :', mae)
print('mse :', mse)
# Out:
# 4/4 - 0s - loss: 88.1044 - mae: 7.5440 - mse: 88.1044 - 56ms/epoch - 14ms/step
#
# loss : 88.10437774658203
# mae : 7.543992519378662
# mse : 88.10437774658203

# %%
predictions = model.predict(x_test)

print(predictions[:5])
# Out:
# 4/4 [==============================] - 0s 4ms/step
# [[25.005878]
#  [22.12614 ]
#  [27.567242]
#  [19.523499]
#  [27.386562]]
