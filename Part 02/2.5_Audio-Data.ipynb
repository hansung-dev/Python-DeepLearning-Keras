# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1.2.5 오디오 데이터

# %%
import os
 
path_dir = '/content/drive/MyDrive/Colab Notebooks/data/TensorFlow Speech Recognition Challenge/train/audio'

print(os.listdir(path_dir))
# Out:
# ['tree', 'eight', 'right', 'bed', 'cat', 'no', 'wow', 'happy', 'go', 'dog', 'three', 'stop', '_background_noise_', 'nine', 'left', 'seven', 'zero', 'bird', 'one', 'sheila', 'down', 'house', 'two', 'marvin', 'up', 'five', 'yes', 'on', 'off', 'six', 'four']
