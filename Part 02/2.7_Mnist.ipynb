# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1.5 MNIST 이미지 분류 (다중 분류)
#
# ## 1.5.2 데이터 구성 및 준비

# %%
import tensorflow as tf
import tensorflow as keras

# %%
from tensorflow.keras import datasets

mnist = datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

print('\ntrain data:', x_train.shape, y_train.shape)
print('test data:',x_test.shape, y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
#
# train data: (60000, 28, 28) (60000,)
# test data: (10000, 28, 28) (10000,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

model = Sequential([
  Flatten(input_shape=(28, 28)),
  Dense(128, activation='relu'),
  Dense(10, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, 
          epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2607 - accuracy: 0.9250
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1136 - accuracy: 0.9660
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0770 - accuracy: 0.9769
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0578 - accuracy: 0.9822
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0459 - accuracy: 0.9853

# %%
loss, accuracy = model.evaluate(x_test, y_test)

print('\naccuracy :', accuracy)
print('\loss :', accuracy)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0803 - accuracy: 0.9760
#
# accuracy : 0.9760000109672546
# \loss : 0.9760000109672546

# %%
predictions = model.predict(x_test)

print(predictions[0])
# Out:
# 313/313 [==============================] - 1s 2ms/step
# [4.1719225e-08 2.0476829e-08 2.5859554e-06 1.0800040e-03 1.2127618e-10
#  8.3666976e-09 1.7820860e-13 9.9888861e-01 8.9814009e-08 2.8686949e-05]

# %%
import numpy as np

print(np.argmax(predictions[0]))
# Out:
# 7
