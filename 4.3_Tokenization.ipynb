# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 3.2 자연어 데이터 전처리
#
# ## 3.2.1 토큰화

# %%
# KoNLPy 공식홈페이지 : https://konlpy.org/ko/latest/install/

# !pip3 install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.4 MB 12.0 MB/s
# ...
#      |████████████████████████████████| 453 kB 71.8 MB/s
# ...

# %%
from konlpy.tag import Okt
#from konlpy.tag import Okt, Mecab

okt = Okt()
#mecab = Mecab()

# %%
okt.morphs('the first story is about connection the dots.')
# Out:
# ['the', 'first', 'story', 'is', 'about', 'connection', 'the', 'dots', '.']

# %%
okt.morphs('첫번째 이야기는 점들의 연결에 관한 것이다.')
# Out:
# ['첫', '번째', '이야기', '는', '점', '들', '의', '연결', '에', '관', '한', '것', '이다', '.']
