# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2.2.2 가상 환경 구성하기

# %%
conda create -n keras-2.10 python

# %%
conda env list

# %%
conda activate keras-2.10

# %%
conda deactivate

# %%
conda remove -n keras-2.10 --all

# %% [markdown]
# ## 2.2.3 가상 환경에 케라스 설치하기

# %%
conda activate keras-2.10

# %%
conda install -c conda-forge tensorflow==2.10

conda install -c anaconda ipykernel

# %%
conda update --all
